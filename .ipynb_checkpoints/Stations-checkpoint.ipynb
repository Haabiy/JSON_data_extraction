# %% [markdown]
# ### <font color='#8db0f0'>The Netherlands' stations</font>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import csv, codecs
from time import sleep
import requests
import pandas as pd
import json

# %% [markdown]
# #### <font color='#8db0f0'> Data collection</font>

# %%
def get_data():
    
    headers = {
        'authority': 'dashboards.nsjaarverslag.nl',
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
        # Requests sorts cookies= alphabetically
        # 'cookie': 'ASP.NET_SessionId=54iuc3nyqiauwwqongsemh0r; _ga=GA1.2.1032039821.1654072543; _gid=GA1.2.1958743457.1654072543; _gat=1',
        'referer': 'https://dashboards.nsjaarverslag.nl/reizigersgedrag/amersfoort-centraal?dtYear=2021',
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="101", "Google Chrome";v="101"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
    }

    response = requests.get('https://dashboards.nsjaarverslag.nl/api/dashboard/2021', cookies=cookies, headers=headers)
    
    return response

# %%
f = get_data().json()
df = pd.DataFrame.from_dict(f , orient='index')
dff = df.T
dtf = pd.DataFrame(dff.Stations)
ff= dtf.to_dict(orient='index')
ff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 f = get_data().json()
#       2 df = pd.DataFrame.from_dict(f , orient='index')
#       3 dff = df.T
#
# Input In [5], in get_data()
#       1 def get_data():
#       3     headers = {
#       4         'authority': 'dashboards.nsjaarverslag.nl',
#       5         'accept': 'application/json, text/javascript, */*; q=0.01',
#    (...)
#      17         'x-requested-with': 'XMLHttpRequest',
#      18     }
# ---> 20     response = requests.get('https://dashboards.nsjaarverslag.nl/api/dashboard/2021', cookies=cookies, headers=headers)
#      22     return response
#
# NameError: name 'cookies' is not defined

# %%
pd.DataFrame(dff.Segments)
ff= dtf.to_dict(orient='index')
ff
